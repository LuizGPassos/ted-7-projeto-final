# %% [markdown]
# # Imports e Dependências

# %%
import pandas as pd

# %% [markdown]
# # Dataset

# %%
df = pd.read_json('./dataset/movie_dataset.json')
df.head()
# Out:
#    adult                     backdrop_path  \
# 0  False  /a3VFDThApTb4lpHfGJQ0oYnJdz8.jpg
# 1  False  /gsQJOfeW45KLiQeEIsom94QPQwb.jpg
# 2  False  /19pr5CzgsBYs67FAJvke8GQxN4g.jpg
# 3  False  /2siOHQYDG7gCQB6g69g2pTZiSia.jpg
# 4  False  /qfAfE5auxsuxhxPpnETRAyTP5ff.jpg
#
#                                belongs_to_collection     budget  \
# 0                                               None          0
# 1                                               None          0
# 2                                               None          0
# 3                                               None  270000000
# 4  {'id': 131295, 'name': 'Captain America Collec...  180000000
#
#                                               genres  \
# 0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2                     [{'id': 27, 'name': 'Horror'}]
# 3  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# ...

# %% [markdown]
# # Análise Exploratória (Para Limpeza de dados)

# %% [markdown]
# ### Análise de colunas (Tipo e conteúdo)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  600 non-null    bool
#  1   backdrop_path          585 non-null    object
#  2   belongs_to_collection  267 non-null    object
#  3   budget                 600 non-null    int64
#  4   genres                 600 non-null    object
#  5   homepage               600 non-null    object
#  6   id                     600 non-null    int64
#  7   imdb_id                592 non-null    object
#  8   origin_country         600 non-null    object
#  9   original_language      600 non-null    object
#  10  original_title         600 non-null    object
#  11  overview               600 non-null    object
#  12  popularity             600 non-null    float64
#  13  poster_path            599 non-null    object
# ...

# %% [markdown]
# ### Validação de colunas numéricas

# %%
df.describe()
# Out:
#              budget            id   popularity       revenue     runtime  \
# count  6.000000e+02  6.000000e+02   600.000000  6.000000e+02  600.000000
# mean   6.203911e+07  6.032627e+05   111.425041  2.878245e+08  112.165000
# std    8.231932e+07  4.866233e+05   174.108752  4.310022e+08   31.357294
# min    0.000000e+00  1.100000e+01    25.061625  0.000000e+00    0.000000
# 25%    0.000000e+00  6.393925e+04    48.224250  0.000000e+00   94.750000
# 50%    2.000000e+07  5.712645e+05    59.781187  6.094703e+07  110.000000
# 75%    1.022500e+08  1.075539e+06    97.680750  4.623667e+08  131.000000
# max    4.600000e+08  1.450432e+06  1794.803500  2.923706e+09  242.000000
#
#        vote_average    vote_count
# count    600.000000    600.000000
# mean       6.720020   6486.865000
# std        1.614679   8366.438229
# min        0.000000      0.000000
# 25%        6.243500     78.500000
# 50%        7.046000   1771.500000
# 75%        7.630000  11673.000000
# ...

# %% [markdown]
# ### Exclui colunas com valores nulos

# %%
df = df.drop(columns=['backdrop_path', 'belongs_to_collection', 'imdb_id', 'poster_path'])
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 600 non-null    bool
#  1   budget                600 non-null    int64
#  2   genres                600 non-null    object
#  3   homepage              600 non-null    object
#  4   id                    600 non-null    int64
#  5   origin_country        600 non-null    object
#  6   original_language     600 non-null    object
#  7   original_title        600 non-null    object
#  8   overview              600 non-null    object
#  9   popularity            600 non-null    float64
#  10  production_companies  600 non-null    object
#  11  production_countries  600 non-null    object
#  12  release_date          600 non-null    object
#  13  revenue               600 non-null    int64
#  14  runtime               600 non-null    int64
# ...
